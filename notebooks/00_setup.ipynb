# %%
# Configuración inicial del entorno de trabajo para el TFG.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta del proyecto en Google Drive
PROJECT_DIR = "/content/drive/MyDrive/TFG-FakeNewsNet"
# %cd $PROJECT_DIR

# Verifico que la estructura está bien creada
# !ls -R
# Out:
# /content/drive/MyDrive/TFG-FakeNewsNet
# .:
# notebooks  README.md  requirements.txt
#
# ./notebooks:
# 00_setup.ipynb.ipynb  99_git_push.ipynb

# %%
# Creo el archivo "requirements.txt"
req_content = """
pandas
numpy
scikit-learn
matplotlib
seaborn
networkx
pyvis
python-whois
ipwhois
sentence-transformers
transformers
torch
joblib
beautifulsoup4
newspaper3k
nltk
requests
tldextract
python-dateutil
"""

with open("requirements.txt", "w") as f:
    f.write(req_content)

print("requirements.txt creado.")
# Out:
# requirements.txt creado.

# %%
import pandas as pd
import numpy as np

print("Entorno configurado correctamente. Listo para trabajar.")
# Out:
# Entorno configurado correctamente. Listo para trabajar.
